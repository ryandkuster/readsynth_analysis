# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # motif only alignments (includes 100u/80c sims)

# %%
df_pear = pd.read_csv('../../../analysis/snipen_2021_update/depth_comparison/pearson_corr.csv', index_col=0)
df_spear = pd.read_csv('../../../analysis/snipen_2021_update/depth_comparison/spearman_corr.csv', index_col=0)

# %%
sns.set(font_scale = 1.2)
cg = sns.clustermap(df_pear, cmap ="Spectral", linewidths = 0.10, annot=True, figsize=(16, 16));
plt.setp(cg.ax_heatmap.yaxis.get_majorticklabels(), rotation = 0)
cg
cg.savefig("many_pearson_corr_clustermap.png") 
cg.savefig("many_pearson_corr_clustermap.pdf")

# %%
sns.set(font_scale = 1.2)
cg = sns.clustermap(df_spear, cmap ="Spectral", linewidths = 0.50, annot=True, figsize=(16, 16));
plt.setp(cg.ax_heatmap.yaxis.get_majorticklabels(), rotation = 0)
cg
cg.savefig("many_spearman_corr_clustermap.png") 
cg.savefig("many_spearman_corr_clustermap.pdf")

# %%
figure_names = ['real1', 'real2', 'real3',
                'A1', 'A2', 'A3',
                'B1', 'B2', 'B3',
                'C1', 'C2', 'C3',
                'D1', 'D2', 'D3',                  
                'E1', 'E2', 'E3']
figure_names_dt = {k:v for k, v in zip(df_pear.columns.to_list(), figure_names)}
df_pear.columns = figure_names
df_spear.columns = figure_names
df_pear = df_pear.rename(index=figure_names_dt)
df_spear = df_spear.rename(index=figure_names_dt)
print(figure_names_dt)
# Out:
# {'mo_real_1': 'real1', 'mo_real_2': 'real2', 'mo_real_3': 'real3', 'mo_sim_1': 'A1', 'mo_sim_2': 'A2', 'mo_sim_3': 'A3', 'mo_sim_mean_sd_1': 'B1', 'mo_sim_mean_sd_2': 'B2', 'mo_sim_mean_sd_3': 'B3', 'mo_sim_100u_1': 'C1', 'mo_sim_100u_2': 'C2', 'mo_sim_100u_3': 'C3', 'mo_sim_80c_1': 'D1', 'mo_sim_80c_2': 'D2', 'mo_sim_80c_3': 'D3', 'mo_sim_100c_1': 'E1', 'mo_sim_100c_2': 'E2', 'mo_sim_100c_3': 'E3'}

# %%
sns.set(font_scale = 1.2)
cg = sns.clustermap(df_pear, cmap ="Spectral", linewidths = 0.10, annot=True, figsize=(16, 16));
plt.setp(cg.ax_heatmap.yaxis.get_majorticklabels(), rotation = 0)
cg
cg.savefig("abc_many_pearson_corr_clustermap.png") 
cg.savefig("abc_many_pearson_corr_clustermap.pdf")

# %%
sns.set(font_scale = 1.2)
cg = sns.clustermap(df_spear, cmap ="Spectral", linewidths = 0.50, annot=True, figsize=(16, 16));
plt.setp(cg.ax_heatmap.yaxis.get_majorticklabels(), rotation = 0)
cg
cg.savefig("abc_many_spearman_corr_clustermap.png") 
cg.savefig("abc_many_spearman_corr_clustermap.pdf")

# %% [markdown]
# # ISO

# %%
df_pear = pd.read_csv('../../analysis/sun_2022/depth_comparison/pearson_corr.csv', index_col=0)
df_spear = pd.read_csv('../../analysis/sun_2022/depth_comparison/spearman_corr.csv', index_col=0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 df_pear = pd.read_csv('../../analysis/sun_2022/depth_comparison/pearson_corr.csv', index_col=0)
#       2 df_spear = pd.read_csv('../../analysis/sun_2022/depth_comparison/spearman_corr.csv', index_col=0)
#
# File /usr/local/lib/python3.8/site-packages/pandas/io/parsers.py:686, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     633     engine_specified = False
#     635 kwds.update(
#     636     delimiter=delimiter,
#     637     engine=engine,
#    (...)
#     683     skip_blank_lines=skip_blank_lines,
#     684 )
# --> 686 return _read(filepath_or_buffer, kwds)
#
# File /usr/local/lib/python3.8/site-packages/pandas/io/parsers.py:452, in _read(filepath_or_buffer, kwds)
#     449 _validate_names(kwds.get("names", None))
#     451 # Create the parser.
# --> 452 parser = TextFileReader(fp_or_buf, **kwds)
#     454 if chunksize or iterator:
#     455     return parser
#
# File /usr/local/lib/python3.8/site-packages/pandas/io/parsers.py:936, in TextFileReader.__init__(self, f, engine, **kwds)
#     933 if "has_index_names" in kwds:
#     934     self.options["has_index_names"] = kwds["has_index_names"]
# --> 936 self._make_engine(self.engine)
#
# File /usr/local/lib/python3.8/site-packages/pandas/io/parsers.py:1168, in TextFileReader._make_engine(self, engine)
#    1166 def _make_engine(self, engine="c"):
#    1167     if engine == "c":
# -> 1168         self._engine = CParserWrapper(self.f, **self.options)
#    1169     else:
#    1170         if engine == "python":
#
# File /usr/local/lib/python3.8/site-packages/pandas/io/parsers.py:1998, in CParserWrapper.__init__(self, src, **kwds)
#    1995 self.usecols, self.usecols_dtype = _validate_usecols_arg(kwds["usecols"])
#    1996 kwds["usecols"] = self.usecols
# -> 1998 self._reader = parsers.TextReader(src, **kwds)
#    1999 self.unnamed_cols = self._reader.unnamed_cols
#    2001 passed_names = self.names is None
#
# File pandas/_libs/parsers.pyx:382, in pandas._libs.parsers.TextReader.__cinit__()
#
# File pandas/_libs/parsers.pyx:674, in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../analysis/sun_2022/depth_comparison/pearson_corr.csv'

# %%
sns.set(font_scale = 1.2)
cg = sns.clustermap(df_pear, cmap ="Spectral", linewidths = 0.0, annot=True, figsize=(16, 16), vmin=0, vmax=1);
plt.setp(cg.ax_heatmap.yaxis.get_majorticklabels(), rotation = 0)
cg
cg.savefig("pearson_corr_clustermap_iso.png") 
cg.savefig("pearson_corr_clustermap_iso.pdf")

# %%
sns.set(font_scale = 1.2)
cg = sns.clustermap(df_spear, cmap ="Spectral", linewidths = 0.0, annot=True, figsize=(16, 16), vmin=0, vmax=1);
plt.setp(cg.ax_heatmap.yaxis.get_majorticklabels(), rotation = 0)
cg
cg.savefig("spearman_corr_clustermap_iso.png") 
cg.savefig("spearman_corr_clustermap_iso.pdf")
